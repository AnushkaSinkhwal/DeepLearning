# %% [markdown]
# <a href="https://colab.research.google.com/github/AnushkaSinkhwal/DeepLearning/blob/main/DL_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing image
from PIL import Image
 # display image in colab
image_colored = Image.open ("/content/drive/MyDrive/DL_1/Lenna_(test_image).png")
display( image_colored )
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
# displaying only the top left corner of 100x100 pixels.

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Loading the image
image_path = "/content/drive/MyDrive/DL_1/Lenna_(test_image).png"
image = Image.open(image_path)

# Converting image to NumPy array
image_array = np.array(image)

# Extracting the top-left 100x100 pixels
cropped_img = image_array[:100, :100]  # Slicing the first 100 rows and columns

# Displaying the cropped image
plt.imshow(cropped_img)
plt.axis("off")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load the image
image_path = "/content/drive/MyDrive/DL_1/Lenna_(test_image).png"  # Ensure the correct path
image_colored = Image.open(image_path)

# Convert image to NumPy array
image_array_colored = np.array(image_colored)

# Extract individual color channels
red_channel = image_array_colored[:, :, 0]    # Red channel
green_channel = image_array_colored[:, :, 1]  # Green channel
blue_channel = image_array_colored[:, :, 2]   # Blue channel

# Display each channel separately
fig, ax = plt.subplots(1, 3, figsize=(12, 4))

ax[0].imshow(red_channel, cmap="Reds")  # Display Red channel
ax[0].set_title("Red Channel (R)")
ax[0].axis("off")

ax[1].imshow(green_channel, cmap="Greens")  # Display Green channel
ax[1].set_title("Green Channel (G)")
ax[1].axis("off")

ax[2].imshow(blue_channel, cmap="Blues")  # Display Blue channel
ax[2].set_title("Blue Channel (B)")
ax[2].axis("off")

plt.show()

plt.show()

# %%
# Loading the image
image_path = "/content/drive/MyDrive/DL_1/Lenna_(test_image).png"  # Ensure the correct path
image = Image.open(image_path)

# Converting image to NumPy array
image_array = np.array(image)

# Modifying the top-left 100×100 pixels to light gray (210)
image_array[:100, :100] = 210  # Setting all RGB channels to 210

# Converting back to an image
modified_image = Image.fromarray(image_array)

# Displaying the modified image
plt.imshow(modified_image)
plt.axis("off")  # Hide axes
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Load the grayscale image using Pillow
image_path = "/content/drive/MyDrive/DL_1/lena_gray.gif"  # Ensure correct path
image_gray = Image.open(image_path).convert("L")  # Convert to grayscale if not already

# Convert to NumPy array (optional, for further processing)
image_array_gray = np.array(image_gray)

# Display the grayscale image using Matplotlib
plt.imshow(image_array_gray, cmap="gray")  # Use "gray" colormap
plt.title("Grayscale Image")
plt.axis("off")  # Hide axes
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Define image path (ensure it's correct)
image_path = "/content/drive/MyDrive/DL_1/lena_gray.gif"

# Load the grayscale image using Pillow
image = Image.open(image_path).convert("L")  # Ensure grayscale

# Convert to NumPy array
image_array_gray = np.array(image)

# Get image dimensions
height, width = image_array_gray.shape

# Calculate center coordinates
center_x, center_y = width // 2, height // 2

# Define cropping boundaries (150x150 region)
crop_size = 150
half_crop = crop_size // 2
cropped_image = image_array_gray[center_y - half_crop : center_y + half_crop,
                                 center_x - half_crop : center_x + half_crop]

# Display the cropped image using Matplotlib
plt.imshow(cropped_image, cmap="gray")  # Use "gray" colormap
plt.title("Cropped 150x150 Center Section")
plt.axis("off")  # Hide axes
plt.show()

# %%
image_2= Image.open("/content/drive/MyDrive/DL_1/cameraman.png")
image_2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512>

# %%
image_gray= image_2.convert('L')
plt.imshow(image_gray, cmap='gray')

# %%
image_gray_array= np.array(image_gray)
height, width = image_gray_array.shape[:2]
height, width
# Out:
# (512, 512)

# %%
start_y = (height - 150) // 2
end_y = start_y + 150
start_x = (width - 150) // 2
end_x = start_x + 150
middle_section = image_gray_array[start_y:end_y, start_x:end_x]
plt.imshow(middle_section, cmap='gray')

# %%
binary_image = np.where(image_gray_array < 100, 0, 255).astype(np.uint8)
binary_image
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
rotate_image= image_gray.rotate(-90)
rotate_image
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
image_rgb = image_gray.convert('RGB')
plt.imshow(image_rgb)

# %% [markdown]
# # Exercise-3

# %%
print(image_gray_array.shape)
height, width = image_gray_array.shape
data = image_gray_array.copy()
# Out:
# (512, 512)

# %%
mean = np.mean( data , axis =0)
centered_data = data - mean
centered_data = centered_data
centered_data.shape
# Out:
# (512, 512)

# %%
cov_matrix = np.cov(centered_data, rowvar=False)
cov_matrix.shape
# Out:
# (512, 512)

# %%
eigenvalues, eigenvectors = np.linalg.eigh(cov_matrix)
sorted_indices = np.argsort(eigenvalues)[::-1]
eigenvalues = eigenvalues[sorted_indices]
eigenvectors = eigenvectors[:, sorted_indices]

# %%
explained_variance_ratio = eigenvalues / np .sum ( eigenvalues )
plt.plot ( np . cumsum ( explained_variance_ratio ) )
plt.title (" Cumulative Explained Variance ")
plt.xlabel (" Number of Components ")
plt.ylabel (" Cumulative Explained Variance ")
plt.grid ( True )
plt.show ()

# %%
k = 30
components = eigenvectors [: , : k ]

# %%
compressed_data = np . dot ( centered_data , components )
decompressed_data = np . dot ( compressed_data , components . T ) + mean

# %%
plt . figure ( figsize =(12 , 6) )
plt.subplot (1 , 3 , 1)
plt.imshow ( image_gray_array , cmap ="gray")
plt.title (" Original Image ")
plt.axis ("off")
plt.subplot (1 , 3 , 2)
plt.imshow ( compressed_data , cmap ="gray", aspect ="auto")
plt.title ( f" Compressed Image (k={k})")
plt.axis ("off")
plt.subplot (1 , 3 , 3)
plt.imshow ( decompressed_data , cmap ="gray")
plt.title (" Decompressed Image ")
plt.axis ("off")
plt.tight_layout()
plt.show()
